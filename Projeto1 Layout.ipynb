# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## COLOQUE AQUI SEU NOME
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\rafaa

# %%
#Se usar o arquivo descompactado
dados=pd.read_csv('DOM2015.csv',sep=',')
#dados2=pd.read_csv('DOM2014.csv',sep=',')
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

#Pergunta: Como redes de streaming de filmes e séries influenciaram na TV por assinatura

# %%
df=pd.DataFrame({'Total de moradores de 10 anos ou mais':dados.V0106,'Tipo do domicílio':dados.V0202,'Acesso à internet no próprio domicílio':dados.V02322,'TV por assinatura':dados.V02272,'Renda per capita': dados.V4621})
df
# Out:
#         Acesso à internet no próprio domicílio  Renda per capita  \
# 0                                          4.0      8.000000e+02
# 1                                          NaN               NaN
# 2                                          2.0      1.150000e+03
# 3                                          2.0      7.930000e+02
# 4                                          4.0      2.900000e+03
# 5                                          2.0      1.990000e+03
# 6                                          4.0      3.500000e+02
# 7                                          4.0      1.333000e+03
# 8                                          2.0      8.180000e+02
# 9                                          NaN               NaN
# 10                                         2.0      1.716000e+03
# 11                                         2.0      2.500000e+03
# 12                                         NaN               NaN
# ...

# %%
dados.V0106 = dados.V0106.astype('category')
dados.V0202 = dados.V0202.astype('category')
dados.V02322 = dados.V0202.astype('category')
dados.V02272 = dados.V02272.astype('category')
dados.V4621 = dados.V4621.astype('float')

dados.dropna(0, how="any")
#dados.V0106.cat.categories = ([])



#f1=dados.V0106.value_counts().reindex(['Sim','Nao','Nao Aplicavel'])
#f1
# Out:
# Sim             NaN
# Nao             NaN
# Nao Aplicavel   NaN
# Name: V0106, dtype: float64

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
